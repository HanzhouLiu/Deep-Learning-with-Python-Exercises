# %% [markdown]
# <a href="https://colab.research.google.com/github/HanzhouLiu/Deep-Learning-with-Python-Exercises/blob/main/GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32768)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = '/tmp/gan_images/'
! mkdir /tmp/gan_images

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# mkdir: cannot create directory ‘/tmp/gan_images’: File exists
# discriminator loss at step 0: 0.6904175281524658
# adversarial loss at step 0: 0.8244485855102539
# discriminator loss at step 100: 0.6952082514762878
# adversarial loss at step 100: 0.787766695022583
# discriminator loss at step 200: 0.6876668334007263
# adversarial loss at step 200: 0.7486155033111572
# discriminator loss at step 300: 0.7070662975311279
# adversarial loss at step 300: 0.9087038040161133
# discriminator loss at step 400: 0.6840928196907043
# adversarial loss at step 400: 0.7771843671798706
# discriminator loss at step 500: 0.6966956257820129
# adversarial loss at step 500: 0.746846079826355
# discriminator loss at step 600: 0.6989060640335083
# adversarial loss at step 600: 0.6976361274719238
# discriminator loss at step 700: 0.6833049058914185
# adversarial loss at step 700: 0.7801110148429871
# discriminator loss at step 800: 0.6906713247299194
# adversarial loss at step 800: 0.757201075553894
# discriminator loss at step 900: 0.6986626982688904
# adversarial loss at step 900: 0.7141104340553284
# discriminator loss at step 1000: 0.6861571073532104
# adversarial loss at step 1000: 0.7696894407272339
# discriminator loss at step 1100: 0.6937922835350037
# adversarial loss at step 1100: 0.7620628476142883
# discriminator loss at step 1200: 0.6823632121086121
# adversarial loss at step 1200: 0.7634237408638
# discriminator loss at step 1300: 0.8616151809692383
# adversarial loss at step 1300: 0.8157938122749329
# discriminator loss at step 1400: 0.6958843469619751
# adversarial loss at step 1400: 0.7438088655471802
# discriminator loss at step 1500: 0.6967762112617493
# adversarial loss at step 1500: 0.8193953633308411
# discriminator loss at step 1600: 0.701861560344696
# adversarial loss at step 1600: 0.7303814888000488
# discriminator loss at step 1700: 0.6964974999427795
# adversarial loss at step 1700: 0.7657933235168457
# discriminator loss at step 1800: 0.697137176990509
# adversarial loss at step 1800: 0.7925187349319458
# discriminator loss at step 1900: 0.7118602395057678
# adversarial loss at step 1900: 0.7724279165267944
# discriminator loss at step 2000: 0.691313624382019
# adversarial loss at step 2000: 0.7323229908943176
# discriminator loss at step 2100: 0.6806225776672363
# adversarial loss at step 2100: 0.7009018659591675
# discriminator loss at step 2200: 0.6947780251502991
# adversarial loss at step 2200: 0.800652801990509
# discriminator loss at step 2300: 0.6761449575424194
# adversarial loss at step 2300: 0.7060807943344116
# discriminator loss at step 2400: 0.6824179887771606
# adversarial loss at step 2400: 0.7912706136703491
# discriminator loss at step 2500: 0.7010422945022583
# adversarial loss at step 2500: 0.7360466718673706
# discriminator loss at step 2600: 0.7389084100723267
# adversarial loss at step 2600: 0.783534824848175
# discriminator loss at step 2700: 0.6887728571891785
# adversarial loss at step 2700: 0.8398210406303406
# discriminator loss at step 2800: 0.6901057958602905
# adversarial loss at step 2800: 0.754024863243103
# discriminator loss at step 2900: 0.7098160982131958
# adversarial loss at step 2900: 0.765511155128479
# discriminator loss at step 3000: 0.7477627992630005
# adversarial loss at step 3000: 0.760215699672699
# discriminator loss at step 3100: 0.6953452825546265
# adversarial loss at step 3100: 0.752568781375885
# discriminator loss at step 3200: 0.727843165397644
# adversarial loss at step 3200: 0.6738715767860413
# discriminator loss at step 3300: 0.6962597966194153
# adversarial loss at step 3300: 0.7431331872940063
# discriminator loss at step 3400: 0.6995644569396973
# adversarial loss at step 3400: 0.6844059228897095
# discriminator loss at step 3500: 0.6859814524650574
# adversarial loss at step 3500: 0.6797798871994019
# discriminator loss at step 3600: 0.6910281181335449
# adversarial loss at step 3600: 0.7212668657302856
# discriminator loss at step 3700: 0.7093014121055603
# adversarial loss at step 3700: 0.7465634346008301
# discriminator loss at step 3800: 0.6722691059112549
# adversarial loss at step 3800: 0.7560409307479858
# discriminator loss at step 3900: 0.6647021174430847
# adversarial loss at step 3900: 0.6487956643104553
# discriminator loss at step 4000: 0.6885778307914734
# adversarial loss at step 4000: 0.7690948247909546
# discriminator loss at step 4100: 0.6735517978668213
# adversarial loss at step 4100: 0.7347291707992554
# discriminator loss at step 4200: 0.7283045649528503
# adversarial loss at step 4200: 0.7404593825340271
# discriminator loss at step 4300: 0.680066704750061
# adversarial loss at step 4300: 0.7859934568405151
# discriminator loss at step 4400: 0.6854488253593445
# adversarial loss at step 4400: 0.8034592866897583
# discriminator loss at step 4500: 0.7306830286979675
# adversarial loss at step 4500: 0.9571409225463867
# discriminator loss at step 4600: 0.6783617734909058
# adversarial loss at step 4600: 1.104779601097107
# discriminator loss at step 4700: 0.8898526430130005
# adversarial loss at step 4700: 0.7179653644561768
# discriminator loss at step 4800: 0.6837457418441772
# adversarial loss at step 4800: 0.8490456342697144
# discriminator loss at step 4900: 0.6965832114219666
# adversarial loss at step 4900: 0.7722610235214233
# discriminator loss at step 5000: 0.7156246900558472
# adversarial loss at step 5000: 0.7414698600769043
# discriminator loss at step 5100: 0.6889787316322327
# adversarial loss at step 5100: 1.0519349575042725
# discriminator loss at step 5200: 0.7070454955101013
# adversarial loss at step 5200: 0.7143117189407349
# discriminator loss at step 5300: 0.6816845536231995
# adversarial loss at step 5300: 0.7719942927360535
# discriminator loss at step 5400: 0.701480507850647
# adversarial loss at step 5400: 0.7873302698135376
# discriminator loss at step 5500: 0.6816092729568481
# adversarial loss at step 5500: 0.7444075345993042
# discriminator loss at step 5600: 0.7109647989273071
# adversarial loss at step 5600: 1.3538284301757812
# discriminator loss at step 5700: 0.7296918630599976
# adversarial loss at step 5700: 0.8102678060531616
# discriminator loss at step 5800: 0.6489899158477783
# adversarial loss at step 5800: 0.8575023412704468
# discriminator loss at step 5900: 0.6677802205085754
# adversarial loss at step 5900: 0.8654931783676147
# discriminator loss at step 6000: 0.6506085395812988
# adversarial loss at step 6000: 0.8087390065193176
# discriminator loss at step 6100: 0.7174214124679565
# adversarial loss at step 6100: 1.0438849925994873
# discriminator loss at step 6200: 0.7045663595199585
# adversarial loss at step 6200: 0.7642684578895569
# discriminator loss at step 6300: 0.6592292189598083
# adversarial loss at step 6300: 0.9229404330253601
# discriminator loss at step 6400: 0.7088118195533752
# adversarial loss at step 6400: 0.729964554309845
# discriminator loss at step 6500: 0.6671484708786011
# adversarial loss at step 6500: 0.678219199180603
# discriminator loss at step 6600: 0.6810840368270874
# adversarial loss at step 6600: 0.7386513948440552
# discriminator loss at step 6700: 0.7494013905525208
# adversarial loss at step 6700: 1.305722951889038
# discriminator loss at step 6800: 0.6319135427474976
# adversarial loss at step 6800: 0.7572416663169861
# discriminator loss at step 6900: 0.6965352296829224
# adversarial loss at step 6900: 0.7392417788505554
# discriminator loss at step 7000: 0.663783848285675
# adversarial loss at step 7000: 0.841107189655304
# discriminator loss at step 7100: 0.7031571269035339
# adversarial loss at step 7100: 0.801906943321228
# discriminator loss at step 7200: 0.6852063536643982
# adversarial loss at step 7200: 0.7827198505401611
# discriminator loss at step 7300: 0.703227698802948
# adversarial loss at step 7300: 0.844037652015686
# discriminator loss at step 7400: 0.6952747702598572
# adversarial loss at step 7400: 0.6765937805175781
# discriminator loss at step 7500: 0.7212921380996704
# adversarial loss at step 7500: 1.0736210346221924
# discriminator loss at step 7600: 0.6984442472457886
# adversarial loss at step 7600: 0.8407219052314758
# discriminator loss at step 7700: 0.7185490131378174
# adversarial loss at step 7700: 0.7873905897140503
# discriminator loss at step 7800: 0.6813735365867615
# adversarial loss at step 7800: 0.7318021655082703
# discriminator loss at step 7900: 0.6407248377799988
# adversarial loss at step 7900: 0.7469322085380554
# discriminator loss at step 8000: 0.6922992467880249
# adversarial loss at step 8000: 0.7841509580612183
# discriminator loss at step 8100: 0.646065890789032
# adversarial loss at step 8100: 0.79670649766922
# discriminator loss at step 8200: 0.7048247456550598
# adversarial loss at step 8200: 0.7944656610488892
# discriminator loss at step 8300: 0.6767163872718811
# adversarial loss at step 8300: 0.7713538408279419
# discriminator loss at step 8400: 0.689394474029541
# adversarial loss at step 8400: 0.7038336992263794
# discriminator loss at step 8500: 0.6816685795783997
# adversarial loss at step 8500: 0.8608490228652954
# discriminator loss at step 8600: 0.6590615510940552
# adversarial loss at step 8600: 0.45873361825942993
# discriminator loss at step 8700: 0.7133776545524597
# adversarial loss at step 8700: 0.649314820766449
# discriminator loss at step 8800: 0.6979692578315735
# adversarial loss at step 8800: 0.8348914980888367
# discriminator loss at step 8900: 0.6945376396179199
# adversarial loss at step 8900: 0.8509200215339661
# discriminator loss at step 9000: 0.6580697298049927
# adversarial loss at step 9000: 0.7431970834732056
# discriminator loss at step 9100: 0.6900889277458191
# adversarial loss at step 9100: 0.8419472575187683
# discriminator loss at step 9200: 0.6895048022270203
# adversarial loss at step 9200: 0.7858006954193115
# discriminator loss at step 9300: 0.9705644845962524
# adversarial loss at step 9300: 1.1694514751434326
# discriminator loss at step 9400: 0.7070640325546265
# adversarial loss at step 9400: 0.6926473379135132
# discriminator loss at step 9500: 0.696718156337738
# adversarial loss at step 9500: 0.7742595672607422
# discriminator loss at step 9600: 0.6466705203056335
# adversarial loss at step 9600: 0.7092252969741821
# discriminator loss at step 9700: 0.7106958031654358
# adversarial loss at step 9700: 0.7129966616630554
# discriminator loss at step 9800: 0.6990371942520142
# adversarial loss at step 9800: 0.8223287463188171
# discriminator loss at step 9900: 0.6782089471817017
# adversarial loss at step 9900: 0.8409422636032104

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()
