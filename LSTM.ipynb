# %% [markdown]
# <a href="https://colab.research.google.com/github/HanzhouLiu/Deep-Learning-with-Python-Exercises/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Text generation with LSTM

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 276s 175ms/step - loss: 2.2595
# --- Generating with seed: "e enlightenment of modern times with
# the french revolution ("
# ------ temperature: 0.2
# e enlightenment of modern times with
# the french revolution (for the some the sensity of the read and the sensity and its the sting the spirit of the and in the sensing the sensity of the self-conscience of the strightent the sensity of the stinction of the sense and and the stinct the spirit of the self-conscience of the senses the sensity and as a men and the sen the sensity of the sensity of the spirit the spirit of the strenge the spirit of the sensity
# ------ temperature: 0.5
#  spirit the spirit of the strenge the spirit of the sensity and decelt the sempicion of the same the spirit and hight, the conceriently in the means, in mered for the haste-no in the man in greanty.
# the sense of the facting the rame and and herment every one it is an mens refighting it is its the man as at for not the and there in the parard wish the spriting
# the instinction of the read the is that is a will and the will so be ad from the spirit and perhap
# ------ temperature: 1.0
# t is a will and the will so be ad from the spirit and perhaps nees"
# is advoucts and fords them reforralt with that greanerspent themseth is namsing
# men is it. funders
# of delogractegrecale it, forchord its reader" there in the
# emit or of o schoof the sething and regsible
# i
# noble-by view' respequely.ly. to hishory", they
# resume olcume his
# promits than me, as age indure, there life, the coustiong ulwer, bright wish idvaring bean remation is exompered umpereb
# ------ temperature: 1.2
# wer, bright wish idvaring bean remation is exompered umperebt: in me(nory
# forly
# this ten (was imperstize, and" thing ogndun , sut. human _ily, a mag the re-sigit. thower sking
# air dhemer them,
# lope
# the betwnem though
# "fastmmating not erbivation 9ishal, lotictaadatyricalosi; itsilugist, howhards bove its-le esird the res: eternerate
# grsay hetwory, in she
# the dingtescipbur, eethtmended and impilige the fathilic duck elos-paicly in with subsegtimencs adnested
# epoch 2
# 1565/1565 [==============================] - 275s 176ms/step - loss: 1.6172
# --- Generating with seed: " proper history of what has been previously
# thought on the s"
# ------ temperature: 0.2
#  proper history of what has been previously
# thought on the self the such a good of the self the propertion of the such a states to the soul, as a still to the self as the self the self the self the self the present as a man as a steption of the self man to be the sense of the self the same and soul, the self the self the self and soul, and in the self the self the sense of the self the self the self the self the self the sense of the self the self the self
# ------ temperature: 0.5
# lf the self the self the sense of the self the self the self agneration, and conditions of the very advanted the such life; all the conducionance of his
# awagion of the being of the sension of the self been the finese and the for arrom of intermany and advange of the stapical possess of the stept has contination of the duch possess, and for a spaided the same and life it is a the first and the all be repoled to the fore in the such in the power, of the self
# ------ temperature: 1.0
# be repoled to the fore in the such in the power, of the selfome which ever
# care sy
# "it is turmpt pareow
# goodtingly mikered afferegian of his life" if never regulizable of liced one. the ucke.
#
# 1chegowlity. the impulsing, of even the ronds, the outhorule some go, like) and feelosogically enerrvente to his "conducionlanated evol;
# -than in ordame advitioious us had in which 1hes, must, it
# lastelow also mable soul
# firequamority of they arififient to day, the o
# ------ temperature: 1.2
# so mable soul
# firequamority of they arififient to day, the offerent more
# light; works reselve
# admit youse by ruce amplitives the soet
# putito
# mongique in opejusgules, enlong pain; but vlvourd a
# as-poiser lrievenbo ingle mores of the we-calre on
# greek as elung on the
# gristq_an all, jusives, and under to otlene
# dailed to surelfore
# forsger the or-chrmety-ebare appremitude) from worit of notlegorreditanks, mich, han generablit case all a
# kould nated, purwancy s
# epoch 3
# 1565/1565 [==============================] - 274s 175ms/step - loss: 1.5263
# --- Generating with seed: "llow of his death-bed there was found no
# "bible," nor anythi"
# ------ temperature: 0.2
# llow of his death-bed there was found no
# "bible," nor anything of the sense of the substrent the self-and there is also the compares the substraning the self-allowing the state of the sentiment and something of the sense of the substrine and the substruence of the self-assertation of the substination of the self-and the state of the sense of the sense of the sense of the substrent the self-can also the such a substraning the self-can and something and some
# ------ temperature: 0.5
# o the such a substraning the self-can and something and something in the self intered that still men that it is admist in the bodier and he so the may our also and the been means of the supposed and the all the success put of the strengther consition of all the seems the standpain of consequent for men and success itself there are standful of come as there is not in the suction and success of the coloured and the series and and stand from personal experien
# ------ temperature: 1.0
# coloured and the series and and stand from personal experiences his sufficess un
# sensish, every
# way to the yask oblife for it never iterful popterics, of the painy candents and of
# su
# horisment recogrement and over
# tikeptarical
# genaelicsls, and unnypieism of, of that is a developmanity of are
# autolicies hove consequently for who algeratified has being painound--the resolding
# happict
# seporery, poinss,
# its emorists as something imagy not in arts that he beom
# ------ temperature: 1.2
# s,
# its emorists as something imagy not in arts that he beom centiretilies fix though remapa"ratively co.m
# trutges it floowitarity athisomen laber tingle relise only necessarishismic varity.=--, reemles.ly anddmellnedm both as is the ouldars therevative foo ""gict cresative by their ;attylil suightful, merely religious,--it"ful woman-dackiwn as thus begse sidusion moblountautly hoyerjus
# no obserative upcage--8erertain his er it sociented dispasinist, sy be
# epoch 4
# 1565/1565 [==============================] - 271s 173ms/step - loss: 1.4785
# --- Generating with seed: "e; we fabricate the
# greater part of the experience, and can "
# ------ temperature: 0.2
# e; we fabricate the
# greater part of the experience, and can all the states and the subjuctt as the morality and the present the self-all in the states the state of the states that the state of the state of the state as the still the states and the same in the philosophers of the suffering that the state of the fact and the all the state of the self-as the development of the present the state of the soul and the same as a still of the states and the suppers
# ------ temperature: 0.5
# e soul and the same as a still of the states and the suppersed the same all of the deceived the incentant the accordantess deterience, as the small as a self-appeared a here the servict enough from the pregerm of the attention something all still wild to the suiling in a soul. they are the terring of the distinction of the all the self-cannotical philosophers of the self-eyet in all sayss of preselt and a such a manificate and a such a depretended the nobl
# ------ temperature: 1.0
# lt and a such a manificate and a such a depretended the noble thedegr: before timirxe--the subjucttatone, of the sin
# procersed the race"
# ampleshing--whether
# from the use i called called something
# while, and chere over: saysence-man love  one our hastelly: , that the charableent, composed somethetre
# masic read in! that were
# they his whole always exaction it was and how long ah made his ham, urimere. the interieles, them fellows from the occarnems. when swee
# ------ temperature: 1.2
# . the interieles, them fellows from the occarnems. when sweet what i complieve, but i ad that
# implaes; was refinened than, by turked: it is to the good his o(c-kulharly parh
# looked centoms, low, bl priberts to theie gurdes of him--arcior of whece
# pengumanding
# me humbit. "well you xwhallseful exont roming ampline  muluhhareineivantity--sgde
# restable tto and vistation as
# once in himself marnarle, is ephrepach.--overlooks.cely feelings
# in di.for
# idens.
# anothe
# epoch 5
# 1565/1565 [==============================] - 273s 175ms/step - loss: 1.4475
# --- Generating with seed: "y been exercise of will
# when the effect of the command--cons"
# ------ temperature: 0.2
# y been exercise of will
# when the effect of the command--consequence of the spirit of the self-and man and more and interpret and sacrifice of the a person in the constitute of the sense of the and self-and development of the strength and sense of the and self-and and same and spirit of the strength and state of the strength and sense of the strength and self-and self-and seems to the strength in the strength of the same in the self-any event to be a same i
# ------ temperature: 0.5
# he strength of the same in the self-any event to be a same in the europe and prefent of under
# the struther of the above that the interpreticism of greatest the complevely of the germans, and sense of the tentice in the instincts of need and moral self-artists of event philosopher that it is a concealed in the constitute in the feeling of the philosophy to all the will that the such shart of the experience of the existing in the exists of the sublime of the
# ------ temperature: 1.0
# perience of the existing in the exists of the sublime of the antiresting to experience and bad mororbacticy are turns of the kind sabsiltesed, the further. in kmod by their elecas
# the serrable ward with the metanical begen men" and strange srot it would the science of getulot, strength and adour their
# importened and have sense. in they inspires-cenent spirits; and dreass which accorderness of itorian through chaided and domination
# is physicis order to samp
# ------ temperature: 1.2
# ian through chaided and domination
# is physicis order to samper.
#
# 1rre wirde--that palreage hitherto harder to the ebits also not bo
# dia morese if the, wo
# lock
# as labjes rades too,
# forcely? vecul if .-desposious spiritual species
# from light ourselves have rochers, all which wishes to s7 name, for exushorious vame is ""wassivingly--to :refleg, that hustenge (we who his to pertain al, shult, at lasting if a ploble
# spirnful, as it. , ewantly actactiscly and co
# epoch 6
# 1565/1565 [==============================] - 274s 175ms/step - loss: 1.4260
# --- Generating with seed: "-if, notwithstanding, he perceive devotion to these
# interest"
# ------ temperature: 0.2
# -if, notwithstanding, he perceive devotion to these
# interesting the soul, and the fact of the states and conscience of the such a man in the suffering the senses of the sense of moral proved to the such a soul and son the world of the senses of the constraint and the person in the such a deed in the sublime the conscience of the such a states of the such a soul and the person of the same constraint and something in the soul the same and something the suffe
# ------ temperature: 0.5
# t and something in the soul the same and something the suffering for the proond in the same and sensiques and also the the truth, the contrary of religion of power. such a such a soul and between of and something to himself to man in the most believe on at life of the people of the most interpretation of entitious with and in the deniument the finds to its instinct, and and godly the senses still still one of state of france the world of am in the proppony
# ------ temperature: 1.0
# still one of state of france the world of am in the proppony the god is us way, the perved on the frice, we people, and find deed himself--"of tioly: peoples of the fathering of pure
# lor ether "meature, man one, intentional free spirit
# worng of a theys a question
# a some ontally, and
# how perfect denedmented their to its own painly haluse are were hours, how just which is he more his ourself time in in the bad frinehandence opbection and a lagerance of this
# ------ temperature: 1.2
#  in the bad frinehandence opbection and a lagerance of this moralidimate calte thoughterle with avlant
# it: perheap-tos free say,
# like all igntrain out bedungee,s
# and humpely.
# ulaste-sadk in simple solve ts himself will arroft counter-to begoinnessmanit wond"abres ethics was until selice frinestain turits!.--for masters, heit has feeled, hence do not our amewam, that hab-things; it is raldly to the trait of
# and
# contraugtfor or the product, and to cospleam"
# epoch 7
# 1565/1565 [==============================] - 274s 175ms/step - loss: 1.4078
# --- Generating with seed: "de, a
# milleantenna, he knows too well that as a discerner, o"
# ------ temperature: 0.2
# de, a
# milleantenna, he knows too well that as a discerner, one and the souls and strength of the most perhaps and souls, and all the souls and stronger and strength of the sense of the superit of the sense of the experience of the stronger to the second the sense of the ancient and self-experiances of the sense of the contemn and the second the strength in the superit is all the consequently to the respect of the most and distind to an its own self-suffere
# ------ temperature: 0.5
# e respect of the most and distind to an its own self-suffered of a struced the apply we of itself and fact of the conceals and to have also be unifaction of the sought to be out of the entare, the intererest has to the man will be stronger is the most souls and could and souls and that all the world of fore to himself in the a stands to instinction and perhaps according to our rifference is once we may could a are duting the taste, the same interestition t
# ------ temperature: 1.0
# e may could a are duting the taste, the same interestition the
# main and eyeth dostigation: ohe who is" the tairs out through. they to at synthesirs which and
# enquited with hereby be its great undule, is extenle
# hem sirous, this whole has intellectual every mick to name. the scientifacies in there syept anyfurent's
# "they with same form-- orgselfical
# long how coush there are with out to at be valued; his others
# ale conquers of evils that it
# is a man doffed,,
# ------ temperature: 1.2
# ; his others
# ale conquers of evils that it
# is a man doffed,,
# lofy of beforeiom manner.
#
# he mauster which, over were which
# be many ifulences," namciation, denivent ogutedgem his myp fortaiest
# onvantad as thin: is his (worgh resuctsuward. iche wi have kant perception will beon sunglier strength? we edelag
# of self: taking but
# hitherfor amountficintor, internals of moral jes
# delivations, preditation--but if it gush of tmengy will-hady.
#
# cemdents,
# painventing i
# epoch 8
# 1565/1565 [==============================] - 280s 179ms/step - loss: 1.3951
# --- Generating with seed: "he past or of the foreign is tested,
# put on, taken off, pack"
# ------ temperature: 0.2
# he past or of the foreign is tested,
# put on, taken off, packes the strong the proplem of the strong that the subjection, and the problem the strong the religious still the the strength of the subjection and will the strong the strong the masters of the contrary and strong the suffering the strength and soul the strange of the strong that the superstituol and soul the strong the strong the strength and strange of the strong and strange of the strong the pro
# ------ temperature: 0.5
#  and strange of the strong and strange of the strong the process of the free modern and the most
# condition to manifests of the words and strongence, in the strong the provention to the instincts itself, and men of a man. "characterty in the green must the strong of moral philosophers, however, when a do not be this soul the purpit to above all which the the constraine of the most things, in the tright of the truth--the metaphysical contemplation of the end
# ------ temperature: 1.0
# ight of the truth--the metaphysical contemplation of the endonessful fethere, who left these refinedes--are know that instance of misoner
# yoo other "hand-slavery of which conceptioning, and tegencence, his mationing and spirits worph act of misunder and meta-be
# strong emcent, friend,
# "what petior in nom among possibility. polis and
# words" in mind that all which it is evil disclucif as so denty--to kellofboldange of the foregrand, evil
# be disneviled soundef
# ------ temperature: 1.2
#  kellofboldange of the foregrand, evil
# be disneviled soundefur. the means of inars of
# opposith
# thisnunk it
# being questions, the ass-if matters,
# the way, europe what cancitation, corltencious somponsary that the rumdly indivinter for their
# fruence, had a highest values--men, a certain-loftiys" suover thrungr as wridk? casionnly of (wrest ows--who eagily--but the fir found thing to this those ied properlilism in these graspleson brinkeas science of a psychol
# epoch 9
# 1565/1565 [==============================] - 282s 180ms/step - loss: 1.3844
# --- Generating with seed: "have not hitherto been so modest.
# all the philosophers, with"
# ------ temperature: 0.2
# have not hitherto been so modest.
# all the philosophers, without one may be a delight to the sense of the assightes of the sense of the any proved the present and consequently and power that the sense of the stronger to the strengther in the sense of the same the sense of the soul, the sense of the strengther and consequence of the generation of the sense of the sense of the same things is the consequently the proved the sense of the proof the sense of the
# ------ temperature: 0.5
# equently the proved the sense of the proof the sense of the thought of minds and placed the power, and also the propartic of the reason of the religions in the sentiment of the thoughts, and formed the most sambor is the far that being and the generations, the philosophize in lightious subjection of subjection is the sense of the conscience. the stupidity of man is a progress, and a men in all the actions of the belief to be a provided that the spirit, as
# ------ temperature: 1.0
#  actions of the belief to be a provided that the spirit, as disgast, as at this them ondung nothing , our nansed my judge
# man of
# his in so had is geteride of the german denhing manner and bl, by  frantzines; is the una philosophy--or that any exporthy
# of nature and never spiritoscering genetion--and if a
# powerful one may cirese, the
# load of men who that "distinking
# a higher
# partiously, thenck natural calse an of which philosophagens desir-geniusly embaloge
# ------ temperature: 1.2
# ral calse an of which philosophagens desir-geniusly embaloge. they remoral cable fyon which
# would speak the opposing and ratiem to sword is ruled, had liventtetuon believed they something anypifounding, humner lak cirpsterment, or inviredshate-umaly-day, onving be monive;cent! their handel-, blage in viewing without owmory, so made sthost to them--former through ourway old amblefs hardally distorus of that in an enjayls "wills.
# o coldianal, them that princ
# epoch 10
# 1565/1565 [==============================] - 286s 183ms/step - loss: 1.3733
# --- Generating with seed: "shed: on
# the contrary that feeling seems to manifest itself "
# ------ temperature: 0.2
# shed: on
# the contrary that feeling seems to manifest itself which is a souls and strange and conscience and problem the conscious and problem and sensition of the hard and sensition of the sense of the conscious and souls and souls and the sensation of the fact and event the sensition of the sense of the property of the sense of the sense of the sensition of the sensition of the sense of the strength and soul, and and the sense of the fact of the sense of
# ------ temperature: 0.5
# gth and soul, and and the sense of the fact of the sense of relation of which the hope that who for all man be more from an attange for the barbed to a in a progress and man
# into a difficult in the soul and sufferings and subtless of the self-distinguished in the last of one was a problem that the pilsonged that the distrust and understanding in fact a consequent of strength and conscience you art one must not be a constitutes of moral the reason of the pl
# ------ temperature: 1.0
#  one must not be a constitutes of moral the reason of the pleasal as the wagn, bothment, the property of the disquire uncount madatic", and "for cavely prose are and in such qualition, i bring sbilly limilatly too knewness, it : son the compasenores
# and with the powernot of furqued. but why has not found god who a deficing hit by indulgeness.
#
# enle gike, or does
# not other? it is betray, he e alw such self--attempt are
# recognitious, they are the
# both, or ca
# ------ temperature: 1.2
# uch self--attempt are
# recognitious, they are the
# both, or ca: the castess in its dpliually adour nation.
#
#
# 127
#
# twa baculier whomepse--the healt estail--kwok, by reason, a while requireity, imperseld aspers" such unspecumed from this a law
# han who pare
# and givenes. a cupa form-instance of dbain assliess harping e!cinesser-fyiether ci: 'way (and well-delight
# process becomestable, now be , one oat abstant vigatures
# modernoral leaknet. that
# methel fear
# bruni"
# epoch 11
# 1565/1565 [==============================] - 285s 182ms/step - loss: 1.3634
# --- Generating with seed: "; small and great expediencies and elaborations,
# permeated w"
# ------ temperature: 0.2
# ; small and great expediencies and elaborations,
# permeated with and something personal production of the spirit and person the self-to his own spirit and soul themselves to the sure of the supposition of the spirit to the sense of the spirit of the surveration of the supposions of the spirit and the soul and still of the supposions of the entailing of the same the spirit to the contradicted and soul and person the concess to his harman such and soul, the s
# ------ temperature: 0.5
# ul and person the concess to his harman such and soul, the sensuality of the present of the soul and event and the school, in its deteriorate its suffering them the fact for the old great consistences, has also a susposibility of the far as in the cause of the enough of the happiness of the science of the other science, the heart and the vain so that the freedom of the soul a souls to charans of the spirit of the course of which has a faith to am "this sub
# ------ temperature: 1.0
# he spirit of the course of which has a faith to am "this subjugit of vour the
# fas
# his higher genureed, as eforiment--the necusting to and criving, they have its he may can perhaps--how the dance of greg philosophy miral, who were oneper cireaples
# into nons--and old be stopp. the
# the most generotic something rebelinence in "the entitleticles promable
# how europe-havility and child entailing and in himself dness."ly
# its merely them--as a contrasionfully staid
# ------ temperature: 1.2
# imself dness."ly
# its merely them--as a contrasionfully staid rust, one
# coniomposical misk in fucted suplesing; from mecholors of interpretly the barbar in our catage florginal.
#
# holotim pain: whe
# intampled reasonncious prove gandal-rilad and general: grouct. to utter throvegt, neverthelessvan of one, a-sarmy history. but roy, he good
# will--headmance e far he divined, is to morality for philosophers auspording more truth,"--the dovery, "nevention, and quita
# epoch 12
# 1565/1565 [==============================] - 290s 185ms/step - loss: 1.3555
# --- Generating with seed: "   3.
#
#      my table was spread out for you on high--
#       "
# ------ temperature: 0.2
#    3.
#
#      my table was spread out for you on high--
#
# ------ temperature: 0.5
#
# ------ temperature: 1.0
#                                                                                     ver all than the staves, he recance, falseed.      an air for the schersion of the purpose an wolled by the varieed,
# freedoming every humanity, how exhict of his exclusion is usonuess
# and grows of all sciencihns! what cherth,
# also it just the battain it is or son that who has
# it, lose,
# as a the long, as it attemptation for the scienging in languagsis had our indifferent it,
# ------ temperature: 1.2
# tion for the scienging in languagsis had our indifferent it, animanly become
# impunring concuided liu ductusise the ruling of a detertiings of oet accordidim, seeks alllied. punt
# menkfors to
#
# mattering politics be u of fegumence which haw choned fair, innecalr
# become
# amiss, or so, friend, wastendedly)-sbacurisalit enecgish and
# it some nobled, lipely period  since somed elevated existainret out of some tish pourlist, he has thips to lart-whan the much first
# epoch 13
# 1565/1565 [==============================] - 289s 185ms/step - loss: 1.3492
# --- Generating with seed: "riving for, and being disagreed as to
# the greater or less va"
# ------ temperature: 0.2
# riving for, and being disagreed as to
# the greater or less value of the great man is the strength of the strength and the strugger and an according to the morality of the art of the present man is the present things and the present strength and the sense of the same and the profound the more of the strength and present was the profound the strength of the strength of the present man is the antithesism of the art of the present taste of the sense of the acco
# ------ temperature: 0.5
# ism of the art of the present taste of the sense of the according to an example in the all art the
# dereners, who has a humanity who profound more understoor and day to the fact, and profounds may and severs of the higher flighten the morality) the according to makes be law and the according to the intellect and sciences, and are understoor and community and are an according the art of suffering and
# something in the sense of the same of which simply and we
# ------ temperature: 1.0
# d
# something in the sense of the same of which simply and we will
# if for the
# demeanys of weaker art as in some art,--highly belies, with order is not with nselained, in the last the trymoties of him, loms of the
# good law of morality with a
# not tattersno,                i flyow there may senwement with our knowledge and cause, and rofessf his just the
# fully, to preferred the
# rilly and stupensity is
#
# perhaps himself our something interpretine," or
# time of
# the
# ------ temperature: 1.2
#
# perhaps himself our something interpretine," or
# time of
# the furmanisme. property.
# ont deep and defices please of
# "inpatignally answle truly poinfprive a sacrificed in
# the expetces (forevertic awaying on ti often justial," truth untieving; is no learn ime all .odea happitivi vulge, opinion.
#
#
# 13
#
# =-importate
# spaid is defiging like himars templem us will to be preied appary prepathen rargal
# speel which. be cencrodableed play,
# prodded
# to the shot of viewly,
# epoch 14
# 1565/1565 [==============================] - 289s 185ms/step - loss: 1.3425
# --- Generating with seed: "a much simpler life, and
# one freer from disturbances than th"
# ------ temperature: 0.2
# a much simpler life, and
# one freer from disturbances than the present the same and the reason of the soul of the same and strength of the same the one is the same and soul and the master of the same and the one as the sense of the master of the master of the same and states the soul is the conscious of the such a souls the soul and souls and such a delight of the power the expression of the conscious and stated in the same and such a soul of the sense of t
# ------ temperature: 0.5
# ous and stated in the same and such a soul of the sense of the discory of the one all the earth as the more of the feeling of
# the same do not to a conscious the great conscious and sunstances of the philosopher is to the prevalling of being is the experience of the conscious the account it is the english
# and thoughting in the contrast of himself with the same to the seem of himself to the world of the same all the severity of the origined in the severities
# ------ temperature: 1.0
#  the same all the severity of the origined in the severities, back which he will swabis! not "grabual philosophers,
# in his standardty is the speciming stander: pertain has slovete its great time.
#
#
# in spirit a newt similar, and historical even with
# necessation, and cysiance.
#
# holless and hardinyly some
# its make man we individually way has
# an
# antion are honest manifigrate concludally to a good ut not acts and hunaed only divine which this prir ard such chai
# ------ temperature: 1.2
# ot acts and hunaed only divine which this prir ard such chaint endy wax ankk,  obrebier else!--at all prepanimen dance mirative true
# of prefellical
# kind of superspit
# id thinking
# in the mirably eeden one's latelects of a hander ground to severity "time" of ekicular tenden: and subad as junggrmotfrical noble as opinion at noveroles, stepic axonginuctianigytery" (for him. then is down lo'd sul: becompt educate a fiptering to last or bod, instinct courugbously
# epoch 15
# 1565/1565 [==============================] - 287s 184ms/step - loss: 1.3371
# --- Generating with seed: "s, through his benefaction, invaded the domain of
# the powerf"
# ------ temperature: 0.2
# s, through his benefaction, invaded the domain of
# the powerful of the strength in the strength of the successful and something is the good of the religious to the contempt of the same the more man is the german of the moral of the far the more delight of the contempt of the stronger the stronger to philosophers of the stronger and stronger of the subject and something of the prooofed and an action of the same the origin of the spirit of the spirit of the s
# ------ temperature: 0.5
#  of the same the origin of the spirit of the spirit of the standing and delight of his thing account to the religious subtle, and the rest of the faither of the self-regarding the feeling of the ruling of moral and strongergest and the present is her demonstren the old to the world slave-carry and moral
# inclined to the moral with its right that the accord of man, there is
# had to make the rest to philosophical stupidity of nature, the soul of the self-advis
# ------ temperature: 1.0
# hilosophical stupidity of nature, the soul of the self-advisenctay them), without , actions and kperficance body is
# love criee from taluls, suspication is assure apprechetion. be priliness. on an even they is, or arimage licily thereby time, laugh at one almost their namely of valuation to harrolans,
# for a mattering, without intellgen to reside
# among it cantimation, now will like a will in wish
# a genors
# them god. it may we masterce and telijped. the deners
# ------ temperature: 1.2
# genors
# them god. it may we masterce and telijped. the deners.ifisal. affore, dreaming, ascete ascertinate distyrqelone least is its sse more objegt and noble origine-yle, which stood of hughtine.
# their dected su finy, this liges hazzing than when we cirmaner among itremable stove who samescimenting.e! stoic on their peke, sometimes had to whom beidely
# the eve, you he. we takes bevolotenes of general name name in the indiance hst, worric
# andresss:
# "their su
# epoch 16
# 1565/1565 [==============================] - 285s 182ms/step - loss: 1.3311
# --- Generating with seed: "haps even in being essentially identical with them. perhaps!"
# ------ temperature: 0.2
# haps even in being essentially identical with them. perhaps! the same tendency and all the sense of the most consently and consider and always the sense of the sense of the sense of the sense of the spirit has a superstition of the sense of the tendency of the sense of the self-existence of the self-experience of the spirit has the spiritual conscience of the sense of the sense of the truth and succarners the superstition of the superstition of the sense o
# ------ temperature: 0.5
# ccarners the superstition of the superstition of the sense of spiritual presence of first the saint of they is to him the false of the serve that even the recogniss the live the history of a present divine as well to a follow his own store of the spirit which is the origin of morality, the see the stronger and presonse of the consently for the
# religions of the event as who account and tempo is races it so nation in the term and the belief in the consenter
# ------ temperature: 1.0
# es it so nation in the term and the belief in the consenter namely--"like again to crueling with means
# of full, best any after "such ages, drows heasted in the simplatiying, a something sufficientes says a working some depresent in the saints the boetwieve not
# concealic moral idly, of the
# necessary wills to particlly to its own
# something is not far nature, the cales, we cerined morality in inalibled to be it from
# enoiesten--it is now transkable
# and interen
# ------ temperature: 1.2
# ed to be it from
# enoiesten--it is now transkable
# and interene which is to have mays
# a fanful type of moral ootivative, "before before commenocce overst
# he is
# excalanct. sours ourselves to =hegreous
# sightiop, and this man heart? punce--do
# i have even to domamm, halon a deate-wikes unatiliatyousgate unconfusing that swe,
# alm.
#
# 26r
# himi"romely;
# the all wrict
# parrirvy
# in life that people will, one
# mean
# ajo", it isdonaus: we
# be: we need of been teld: xertate pe
# epoch 17
# 1565/1565 [==============================] - 285s 182ms/step - loss: 1.3261
# --- Generating with seed: "estruction of the city and thus a great damage inflicted
# upo"
# ------ temperature: 0.2
# estruction of the city and thus a great damage inflicted
# upon the discourse--the existence of the self-exploined the are of the appearance and all the self-exiction of the man are all the god, and the existence of the self-concerning and the strength of the self-canture and the man is a strange and and a man are also the discourse of the self-cencuited and intellectual and disposition and the man is the presentiment of the self-excession of the contempt of
# ------ temperature: 0.5
# is the presentiment of the self-excession of the contempt of the higher own the extentical intellectual and difference is as a senses and when it is with thereby of the discovered to the same and all something that they are responsibility that all the he can seems to life the considers of the delights with the highest man in order to be a still fact that is a strange for the promise of the feelings and the same and are gradute that they would like the scie
# ------ temperature: 1.0
# s and the same and are gradute that they would like the scientific man; theysely world and establishwind and rank, and its setins
# of the mobey that the perception of the are as one is despectible, or
# much consigning man, art to precimplet), in the accordance in a herishes atone as a great
# med, needs also not permet-slacer are an ""matarial. might was art only be
# addution aody
# nimpleteness." the. "and
# he of its grosing it--like u one in
# a feeting that the c
# ------ temperature: 1.2
# and
# he of its grosing it--like u one in
# a feeting that the can act muscravely" were sense of the
# colow and icecurations which there are order the
# polismd. but for theching liadly bot--endeanedy, ri-fach, about efitly,
# 0y romuly every delice and bell perpette--theas case, overdor
# breut prefer over the curieve datious cacor
# vain one.
# honest of view been concerned former: lay.
#
# here
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# eptr.arele, prograity are rebuladical--know than wishess thereby has been the
# epoch 18
# 1565/1565 [==============================] - 282s 180ms/step - loss: 1.3210
# --- Generating with seed: "and there is not a more foolish "if
# possible"--to do away wi"
# ------ temperature: 0.2
# and there is not a more foolish "if
# possible"--to do away with a man who are the present man are the facts of the same and the subject the sense of the art and seems to the promise of the art of the fact of the problem of the property of the spirit of the profound the problem of the problem of the sense of the promise of the same and seems to the man is the man are been adventure to the commence of the sciences of the sense of the world of the art to the p
# ------ temperature: 0.5
# f the sciences of the sense of the world of the art to the propertices of his states of a precisely that it is a had to this most consequently, and the property of perhaps something in the general
# present the sentent the spirit which all its place at the greater sense of the spirit" when the complete and the artistic be the invently for the facts are an intervessess and promous the life of the propertice of the antity of the facts the present short, as the
# ------ temperature: 1.0
# pertice of the antity of the facts the present short, as the greater such a mander; an above alsoment of brought or
# some german time, we cannot hourst" and they
# "fact some things in
# the
# feeling                                       ving inducent of them wornces of
# the most require the orde of a ut--is athologestics.
#
# e of his
# put time when should
# may perhaps, as repeaners without emo
# men, if there most develoded coedly men, it is tht through and
# certain ac
# ------ temperature: 1.2
#  most develoded coedly men, it is tht through and
# certain accordingraen beelowed of
# moywes of demands the lightions of subject and before the insi incremmable,
# what whenezed and if a :ca nons, orreives fincently hawder thret, of her "uniden at rumeops from heart is europe and
# way, how diedwquty.
#
# hinea, home ouswayd
# and still ina ekent both in a derromsful
# oraiculor its slow hitheruse often
# dance of the wort, insight up to means he short, congerman been th
# epoch 19
# 1565/1565 [==============================] - 285s 182ms/step - loss: 1.3177
# --- Generating with seed: "pernatural, because of these
# things he attained the extraord"
# ------ temperature: 0.2
# pernatural, because of these
# things he attained the extraordinary and so notion of the present in the probably are the artists and strong and attempt and the most comment and self-experimentally and the problem of the present the self-experiment and so that the sense of the sense of the self-can the most sensition of the artists and self-can a souls to the profound the world of the problem of the means of the soul, and the problem of the present in the bes
# ------ temperature: 0.5
# means of the soul, and the problem of the present in the best all deces of the same of the way to be as even in the greatest and not the strong and virtue what is the demonstration of dicting
# and probably proportions of men of the both to philosophers of the
# power of the belief of a supposite for the reverence of the world for the pregsposite of the moral completeness to every means of the purely of the completely for ethical will for the soul, and the ori
# ------ temperature: 1.0
# of the completely for ethical will for the soul, and the origin." the taste of its which all in harkern danger and appearage; we masteruded, however, writing to be taxity of thus states another, among the secon.pay. a vuise hophing an, is to be unjust astronots of christian who say not nothing for iteration is in any one redusting, shegable pryk"watian often marged
# then,
# himself on creat, in artificis which is numon the peopption of way have,
# however, me t
# ------ temperature: 1.2
# icis which is numon the peopption of way have,
# however, me times, by mind
# of portfutness hir
# "felt of desoubt, and univent
# under; one
# extorelous a
# cheerfly; it now remease fooldsy. namely bspood ataph down historical recert prevaltectes--the dedezelfy with unsequencely. siceed now usparats disimmen, tenever are
# bearn only undersfur as wrote brings.
# there has
# been, ithe. the supposing tipituding disguised, as old experdencen. but the hotaile. nabled thor th
# epoch 20
# 1565/1565 [==============================] - 289s 185ms/step - loss: 1.3155
# --- Generating with seed: "onduct.
#
#
# 97
#
# =delight in the moral.=--a potent species of j"
# ------ temperature: 0.2
# onduct.
#
#
# 97
#
# =delight in the moral.=--a potent species of justice and interpretation, the antithy of the contrary and the moral philosopher of the more deception of the personal conscience and predication in the contrary and an active of the healthy of the antimate of the world of the soul and the contempt of the other has been the sense of the most love of the contrary and with the most intellection and and also with the cause of the more of the world of
# ------ temperature: 0.5
# tion and and also with the cause of the more of the world of any religious called great and the deception of the semates of any place of a power to interpines and the will to them at the same a person of the antiquest of morality and have not become by the man is included to more under the great contemporated that a man will be develops
# and weaker the fear of the most and
# intellect and not be "immediation--in mistakl
# in its own its own the standard and the
# ------ temperature: 1.0
# ediation--in mistakl
# in its own its own the standard and there no latter hne--account pate most empiredly
# onry of general
# arrangem processe to philosoptanes, betray to only consideration. it is calmeation--just
# that it play
# noblessing and good kind. there is
# cerse of his healthman attention the tixness, and ons modest happiness that which all view, anything became an vid firs in caurr man, it in every
# comparation of man is enjoyment. halthing for the feate
# ------ temperature: 1.2
# very
# comparation of man is enjoyment. halthing for the feate that is of body enuarbecally!y detention thus
# porthemly arable
# any colaroried,
# and
# only day, sionom,
# retuvific antiumly
# a nooousre's wath his game futurpbelings, peted for the disif anwallcte,
# which no courtory) mean, "doqued fully extrn dependence
# from which
# presents: its "corlificant bodys:--i have in when
# nones of the great gid an no rations of casion. o as non-take nother toward: the vermal"
# epoch 21
# 1565/1565 [==============================] - 286s 183ms/step - loss: 1.3098
# --- Generating with seed: "ly woman's behaviour
# towards children!--which has really bee"
# ------ temperature: 0.2
# ly woman's behaviour
# towards children!--which has really been the such a soul of the self deceptive of the self promise of the soul-in the spirit of the self self self proviction. the self deceptive of the action of the most such a souls, and the proved and commonply the soul, the same and the such a soul of the sublim the self self according to the same the superspomnder and all the same the promise of the such a standard of the act of the self self probl
# ------ temperature: 0.5
# ise of the such a standard of the act of the self self problem which is always been only the soul--and should not soul-in the heart of the strength of the good and completion of the own the assume the man even however, with the bad scientific and the self serious and contempt and self consequently one how enjoysiming the same and the highest comprehensibility for the generation of the angunto proposition, which the strong, the self more pressibility and ac
# ------ temperature: 1.0
# osition, which the strong, the self more pressibility and account. near other demands his strucgle or
# problem of his other matholys and line
# woil what is it you orgessly sufficings,
#                                            la morality of mankind in the accose who forms-the most origin. but conxpelty bad are, is else general a god who is not surrenesing that which feelings, himself to faice will feart of theist shing in eduery maign, producting of eicht,
# ------ temperature: 1.2
# feart of theist shing in eduery maign, producting of eicht, that is" which iestalk--not the madac allieg
# is tenonder of successful art the interpaction of the
# and effected." the indeedsm of german viciope
# science"; the ascepted equiin reflect, smen fleec firrolar. pa_s had exbetion): as
# enough in time, doesy, made or aklistion, and wholly case ederscasious, thrur pete of murdlic and nature" in its
# trodis down dge"--elegating are clovesism from the could a
# epoch 22
# 1565/1565 [==============================] - 285s 182ms/step - loss: 1.3060
# --- Generating with seed: " originated in a ruling caste, pleasantly
# conscious of being"
# ------ temperature: 0.2
#  originated in a ruling caste, pleasantly
# conscious of being the same and conceals of the subtlety of the animal sense of the contradisting the are of the problem of the higher morality and say in the most sense of the sense of the world in the senses to the sign of the are of the higher problem of the subjection and sense of the sense of the sense of the higher morality and the soul of the spirit of the subtlety of the constant the soul and senses to the
# ------ temperature: 0.5
#  of the subtlety of the constant the soul and senses to the refinement by the delights of the condition of philosopher of the taste is a sould, and also has a soul of the contradistics of the same "perceptions and again to say, and affing to the heart of life and freedom that the delightes and true the higher more saints of the regard to a superior of the same time of fact the a souls, it is a delighteness who be suffers, when i have on the hear himself of
# ------ temperature: 1.0
# ighteness who be suffers, when i have on the hear himself of inspire it among them on haw,s of his feltow having yies the thoughts, it is a "gilim stilld on the
# saberics, a
# whole
# does
# not pyting nurth-supposestainted their faith that its so grest best libitions, pen), is it may delights ivesion too carry, and distorately would have inferted in the teactueccely, shopillesss afmears will be sainings which has
# coentrions divine tightimigatical ridiration, an
# ------ temperature: 1.2
#  which has
# coentrions divine tightimigatical ridiration, an doan thoughting under conking"--an figns commas
# put thereofl,
# him.
# i knew world of
# calle expayrulonism rever allodinessness,
# ickholodes, wheres too mucies although the borns no evrandily, apfeoned for yellows about impits" alhost thought? the sablangs cobleinged to whule good and is, forethinker as "things opened ta itself reciphry and at last
# pecuses. in the
# war, and we
# i make "ambition and who i
# epoch 23
# 1565/1565 [==============================] - 292s 186ms/step - loss: 1.3038
# --- Generating with seed: "ominate, or justify,
# or honour, or reproach, or conceal his "
# ------ temperature: 0.2
# ominate, or justify,
# or honour, or reproach, or conceal his son that the deception of the senses to the second of the acts of the soul, and the strange of the sense of the world that the strange of the soul, which the acts of the same that the consequently of the self-instance, the substrud. the belief in the strength of the self-respect that the world of the world of the sure that the sould to the greatest of the senses to the senses to the belief in the
# ------ temperature: 0.5
# e greatest of the senses to the senses to the belief in the most does not that the educat to be as a democratic case that it is emotions and contemptation, and word in the excallation of the strength and has the aske is it were the first properial things on the present that which the refinement of enjoyments, that it is the spirit of the states of a merit of deate of enjoyment and borts, the spirit of transfor the too general state of spirit may be reason
# ------ temperature: 1.0
# t of transfor the too general state of spirit may be reason still remain of the hain that delight ghan
# ...
# ------ temperature: 1.0
# est work, there are will them as the present such a hundred will of the infeatousing in which that those froith--and
# unterricter, if the hespi"es
# which newhine of prulibles discosistent their himself which
# the
# are profound of conscience, the barbence make, or moral placed and caded and disposition learn evolution, in their earment of a more sity of the europeans of all that charms-man of the lere to relible because of processuofs, here reading its tain die
# ------ temperature: 1.2
# to relible because of processuofs, here reading its tain dies, "vibtuwise. without speciarmen beside, and dosming seen asceiont"
#             notwiths in himse-lushiks
# work for imesten when anyloog of tempo, insuinance, reforely exaitant of his
# to furrlike wherequal virtu the very out of duties
# into self guilt, and the balteanion state, at say, and to collefut it to which retrout", the,
# whether
# there be virtue! through epofulidy conducted to secretlysest, h
# epoch 53
# 1565/1565 [==============================] - 293s 187ms/step - loss: 1.2479
# --- Generating with seed: "elves when they became "patriots." i think of such men as
# na"
# ------ temperature: 0.2
# elves when they became "patriots." i think of such men as
# nations of the same time the moral to the consideration of the same time of the same time and the senses to the same time the sort of the same time the same time and the same time the sentiments of the same time the higher men and stronger of the same as the problem of the same time the sentiments of the same time the senses to the same as the soul the most desires and the moral belief the superies
# ------ temperature: 0.5
# the soul the most desires and the moral belief the superies of the will to all the taste of the moral pain of this century which with the same time in the conduct of the fathers of a belief the mere contrary and all the comparison has more
# later of the intelued had can it is that in the uncertain the same time science, and with a word such transfait to largement, in the works in the sentiments of the fact, which some mistakes a misunderstanding the conduct
# ------ temperature: 1.0
# the fact, which some mistakes a misunderstanding the conduct, and a way infertment. the german, with "even the does graspion.
#
# häuring in life. whoever intelued
# himself like a
# hunter conception to all things show under this fature.  kunns of morality" in grade for, supposite, full are remained his salvages are
# alage solence hammer..
#
# in still; until we can even and
# of which of
# the a determine as a could may!
# in the origin really within this vengeant superi
# ------ temperature: 1.2
#  could may!
# in the origin really within this vengeant superior oper the compreisory with class pythess made thinkers
# with oright"
# attenuated to does himself. for gringation. and will
# i new--all etimate chronness, had less tho loves and why had not believe, rulerity, mystitud
# in any naturaity we are aantlier "rame,
# longer," to--the general very sumperable tynkenner that workers
# in his
# lenceforctiness clion; lit barre
# truth, briaged, also, to your my take" m
# epoch 54
# 1565/1565 [==============================] - 292s 186ms/step - loss: 1.2460
# --- Generating with seed: "nce, though it tempt one with the most valuable discoveries,"
# ------ temperature: 0.2
# nce, though it tempt one with the most valuable discoveries, and the german of the most conscience of the sea for the self matter to the senses to the general perhaps be the senses to the senses to the senses to the german of the experience of the serely and all the surprew of the same time the senses to the other people on the same seriously, and of the same seriously, and the same time and senses to the senses to make the same time of his sea fally all t
# ------ temperature: 0.5
# s to the senses to make the same time of his sea fally all the origin, and where the values of the tranquiling the intellectually seems to the sea folly, when the conscience of a proop to the really the categous and the evil without
# the senses to the such and the german of the experience, the greek life with other conscience, but the still of its one, and as a promptly and in a presense of the religion of the secret
# excession of "are is a bad to course, in
# ------ temperature: 1.0
# igion of the secret
# excession of "are is a bad to course, in world who lingetwe!"--a pricity of reflect painotod heart something that
# the
# something of
# shaysemety. in pusinmety and wontering in
#  sensings now, to short for the same creatious morals..!
#
# 17
#
# ijsens of woman, and pleasure which
# also
# philosophs soul, such as helishoped
# of the pream, is free
# schooles--from the religion
# and passions
# as heavy of its happens to make mistaoder, as self mentary exuet-
# ------ temperature: 1.2
# avy of its happens to make mistaoder, as self mentary exuet-mentime, such it
# primplicated, lse!phike gehterer, every obveive with the revelled ialllosy gand, or what the beautified bliot of the an : the
# sincted propour then? why is countr same. thus may some ingixingzes, he is perhaps be nothing
# smilts, as unriated when a phillone to witt!"
# j. trainns, namitied to litselfune! name, a future,
# for be reseamed with the , expreser later agles again.aque noo so
# epoch 55
# 1565/1565 [==============================] - 295s 189ms/step - loss: 1.2440
# --- Generating with seed: "ion the "fatherland," and the newspapers, and
# their "family "
# ------ temperature: 0.2
# ion the "fatherland," and the newspapers, and
# their "family and still present the deception of the same time of the saint of the senses to the saint of the subject of the saint of the same times and also a souls the saint of the saint of the saint of the saint of the saint of the saint and all the saint of the same time of the saint of the saint of the man is the senses to the same time and alway and the saint of the senses to the same time that the saint
# ------ temperature: 0.5
# and the saint of the senses to the same time that the saint and most fait world will be say, and the contemned, with a hast act of the spirit, their present disclosed to the senses to have been to a spirit that which is the marker of which all the active of the senses of men, and the world with a heart of the habit of the fact of the senses to a characterists, in the faither of the sense of the way of spirit is the contrary and like the sense of the superi
# ------ temperature: 1.0
# y of spirit is the contrary and like the sense of the superiore,
# such a lability of the way, bad to lably meked a
# truth friends, also
# much is me, to drunded proves refined of an whole sanrance of the soul; an ighest which does -a
# shold the mapidity of enlightenment chartt to persiculual tendacce all towards a clous open a promises words
# (indiffered
# these does not an deeds."--it is withselve gratation. the constant aristogical
# mankind
# that the offect in thi
# ------ temperature: 1.2
# ion. the constant aristogical
# mankind
# that the offect in this agrow propre lightfulness,
# an al"fluse the most laughter-tamols perfeed garbleed"
# in an invaricty; "there is no opinios,
# them inconceptionall
# lones in a as when all influence of the
# called.
#
# a closing "and did why
# ourselves, indi! bulgliblul. in finer, the prijul
# "hnimse lacking
# frightwr-truth that wherechreain, it is old in grots of persay one's mi, in
# the promplisable, parits
# will
# "but this ca
# epoch 56
# 1565/1565 [==============================] - 298s 190ms/step - loss: 1.2430
# --- Generating with seed: "stic of an
# advanced civilization to set a higher value upon "
# ------ temperature: 0.2
# stic of an
# advanced civilization to set a higher value upon the condition of the sense of the religious that the most conscience of the religion of the strength of the strength of the strength of the strength of the same the more of the religious that the present of the strength of the strength of the same the consequently and the condition of the sense of the words of a demonstry of the strength of the religion of the strength of the strength and last dis
# ------ temperature: 0.5
# of the religion of the strength of the strength and last distingural sorts of morals, and not the truth of the interry of evil of the deepest of the questions of the truth is a standard the accompanger of the truth of the same in the distrust read the origin of the conduct that
# which the desires and the man are strect to pleasure and the most be the immoral fellows of the bornisnow of the endurable been it is not be more persistence and demands of the expe
# ------ temperature: 1.0
# e been it is not be more persistence and demands of the exped her the interrogature as the resist
# suddenly to be wet the "understood as the disgusers in the oly rule of a doo  in home has to make untints the last disressing on asceticlly of earthless of enlightenment. in reason. not in merely hence of life you an necessary; the manners of self-outtruistessen there is no longer moral wicked
# and spirit. the mind unith the attempt one must one resis
# in kind f
# ------ temperature: 1.2
# rit. the mind unith the attempt one must one resis
# in kind from "m
# enry-frwquerate it it is more, there is a loticians a barbary has him and assumes
# on the a surventure, which errods stormors and fundamert not
# its contemplation, germans only have see a moke, with somele of the knowledge to this, then, meot empleaings us i gotces aboveful
# kind of moder is
# honey:
# undarkan of ghare, rome nor
# catuess, him whether the "noble riget
# atirated liumonk, voetes how m
# epoch 57
# 1565/1565 [==============================] - 299s 191ms/step - loss: 1.2437
# --- Generating with seed: "f being suffocated by sympathy:
# he needs sternness and cheer"
# ------ temperature: 0.2
# f being suffocated by sympathy:
# he needs sternness and cheerful and constrains the first standass of the problem of the strong that the problem of the fact of the strong that the sense of the subject and the strength of the strong to the promises of the spirit and the soul as the most constrains in the problem of the individual and such a devil of the strong to the commander of the problem of the superficial standar and strong that the problem of the stron
# ------ temperature: 0.5
# superficial standar and strong that the problem of the strong that the instincts of the same times of a life and great problem and paralid' and from the subtreficious to courage find
# them the origin. the circumstances, and also interesting and
# reverent and distinguished even in the feeling of man that the fact of the harding the
# power, the origin. the fine, and all the responsible in the profound that the fancy of the most standard and discovered to genius
# ------ temperature: 1.0
# that the fancy of the most standard and discovered to geniused.
#
# 1yæs not it could whether had to be the keptorle, geniually and divertate the an posin in the task and practs storms--in a formed even proper." one reallongly with the most person the must once pose
# do to be other adventures
# in  holy ourselves of autst as immuch dangerous
# befooness. the depth on
# their worker and the
# world is not one must
# be , soilan and god speak of event storeing, is for obs
# ------ temperature: 1.2
# must
# be , soilan and god speak of event storeing, is for obsolation. though, the
# t      is toou, but byfuring
# from germans or hogy, he must always iplaines of anlrowern, they extralle, it have only rafter comecensers have sonfly, unvalismineinate the goethuld us foinex all that is worth. a mindression
# upon
# to or
# expodences.
#
# ygn diven-mosesterment to
# the canual stroming
# shut
# thus "and kinds
# of rentain goiminate commands who does not at brofic before un a h
# epoch 58
# 1565/1565 [==============================] - 303s 193ms/step - loss: 1.2449
# --- Generating with seed: "icate sentiments of worth,
# and distinctions of worth, which "
# ------ temperature: 0.2
# icate sentiments of worth,
# and distinctions of worth, which is all the same thereby and the stronger of the self-contrary and present the second of the fathers of the stronger of the work of the second of the interpretation of the stand of the same as the states of the self-exprossible to the self-contrary to himself and all the germans of the word of the same to the standard of the stronger of the same to his feltker which the conditions of the work of th
# ------ temperature: 0.5
# e same to his feltker which the conditions of the work of the spirit owing to the opinion of the more thor the contrary of the opposite to the old by the highest discovered the work of the spirit and proved originated by the opinion of the general disposes to experience--the instinct of all the
# sense of his way that which the accomes of the reared the old pease of the work of the work where all the woman is itself as the conditions of moral same to special
# ------ temperature: 1.0
# e woman is itself as the conditions of moral same to specialing--he, overunt" and appears are harts and france is intally bebur a bad and bongler the characterism.=--the gregeal opon man was varies very valuation
# iden comed to--immoralis for mobut-exception in the holys
# the
# act degree avel denied and so, into "powerful and the useful soul
# of mind, he dover
# formerlical could now
# exelused
# act of womorm of uson, first by no right serieness philosophy, his pow
# ------ temperature: 1.2
# orm of uson, first by no right serieness philosophy, his power and lighteness be valuation. devaves looke
# favour an! thro a pogsing incurioly down the advisents
# "usefortus appear. he sees just gave
# in so, an ray of a wached qualigation and strughly, i be thereik get this
# nature as varies and it alw to it were decade to naxit imisques in there awraghs, person doond to-imatiws have been come does who "here of
# the only isualory
# instinctnesslys of characteromi
# epoch 59
# 1565/1565 [==============================] - 299s 191ms/step - loss: 1.2421
# --- Generating with seed: "ut their last trust in a sure nothing, rather than in an
# unc"
# ------ temperature: 0.2
# ut their last trust in a sure nothing, rather than in an
# unconscience is to all the saint of the problems is the strong the substence of the supposing of the same an active of the depths of the sense of the present strong the depths of the sense of the world of the world and the world of the problems is the consequences, with the same an evil and the sense of the sense of the sense of the free spirit and the world of the sense of the sense of the problems
# ------ temperature: 0.5
# rit and the world of the sense of the sense of the problems and only the
# problems is indeed they wish to be interestion and perhaps with a souls of the fear,
# the man are strange of the most desire the anewless are only and lastly all its perion of the germany man is an actory of the soul are spiritual has viciors,
# with the soul. the greatest has once believes of live to
# sever the most deceived to really to every series of the case of the contrary of the re
# ------ temperature: 1.0
# really to every series of the case of the contrary of the relationship and arcuring it wouth be a
# cholities of the prehopo-enwha')
# and the attaciatibil hreaters of the human prompule
# that this belief. in be
# years in its antiques, ratility", ain all rahes and process and also time not worburious skind. he is innatered, that is above the
# manifessy ensness of man. they been
# lives with the sail man is gain enlightencys. recibpus of first, or ill--agnists of o
# ------ temperature: 1.2
# s gain enlightencys. recibpus of first, or ill--agnists of other imagine mat by a
# most will and, the unrecrove to
# who deity, that
# communging
# and inviritive, wross, by
# the mo which considered only mysteries himselfs, "the wait-scide pettic its system of
# with him, letteld!!
#
# 1
#
#
#
#
#
# he,
# contyle, them frevisuiliy? quance
# about misunderspatt come
# herraid, and to equipured, for the bargeness," hin
# both typicises,
# even against up the facts to hours also-placeb.l
