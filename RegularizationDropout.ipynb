# %% [markdown]
# <a href="https://colab.research.google.com/github/HanzhouLiu/Deep-Learning-with-Python-Exercises/blob/main/RegularizationDropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results

# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)
# Our vectorized labels
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

from keras import models
from keras import layers

original_model = models.Sequential()
original_model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model.add(layers.Dense(16, activation='relu'))
original_model.add(layers.Dense(1, activation='sigmoid'))

original_model.compile(optimizer='rmsprop',
                       loss='binary_crossentropy',
                       metrics=['acc'])

smaller_model = models.Sequential()
smaller_model.add(layers.Dense(4, activation='relu', input_shape=(10000,)))
smaller_model.add(layers.Dense(4, activation='relu'))
smaller_model.add(layers.Dense(1, activation='sigmoid'))

smaller_model.compile(optimizer='rmsprop',
                      loss='binary_crossentropy',
                      metrics=['acc'])

original_hist = original_model.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512,
                                   validation_data=(x_test, y_test))

smaller_model_hist = smaller_model.fit(x_train, y_train,
                                       epochs=20,
                                       batch_size=512,
                                       validation_data=(x_test, y_test))

epochs = range(1, 21)
original_val_loss = original_hist.history['val_loss']
smaller_model_val_loss = smaller_model_hist.history['val_loss']

import matplotlib.pyplot as plt

# b+ is for "blue cross"
plt.plot(epochs, original_val_loss, 'b+', label='Original model')
# "bo" is for "blue dot"
plt.plot(epochs, smaller_model_val_loss, 'bo', label='Smaller model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

bigger_model = models.Sequential()
bigger_model.add(layers.Dense(512, activation='relu', input_shape=(10000,)))
bigger_model.add(layers.Dense(512, activation='relu'))
bigger_model.add(layers.Dense(1, activation='sigmoid'))

bigger_model.compile(optimizer='rmsprop',
                     loss='binary_crossentropy',
                     metrics=['acc'])

bigger_model_hist = bigger_model.fit(x_train, y_train,
                                     epochs=20,
                                     batch_size=512,
                                     validation_data=(x_test, y_test))

bigger_model_val_loss = bigger_model_hist.history['val_loss']

plt.plot(epochs, original_val_loss, 'b+', label='Original model')
plt.plot(epochs, bigger_model_val_loss, 'bo', label='Bigger model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

original_train_loss = original_hist.history['loss']
bigger_model_train_loss = bigger_model_hist.history['loss']

plt.plot(epochs, original_train_loss, 'b+', label='Original model')
plt.plot(epochs, bigger_model_train_loss, 'bo', label='Bigger model')
plt.xlabel('Epochs')
plt.ylabel('Training loss')
plt.legend()

plt.show()

# regularize
from keras import regularizers

l2_model = models.Sequential()
l2_model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu', input_shape=(10000,)))
l2_model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu'))
l2_model.add(layers.Dense(1, activation='sigmoid'))

l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

l2_model_hist = l2_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))

l2_model_val_loss = l2_model_hist.history['val_loss']

plt.plot(epochs, original_val_loss, 'b+', label='Original model')
plt.plot(epochs, l2_model_val_loss, 'bo', label='L2-regularized model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()

dpt_model = models.Sequential()
dpt_model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
dpt_model.add(layers.Dropout(0.5))
dpt_model.add(layers.Dense(16, activation='relu'))
dpt_model.add(layers.Dropout(0.5))
dpt_model.add(layers.Dense(1, activation='sigmoid'))

dpt_model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

dpt_model_hist = dpt_model.fit(x_train, y_train,
                               epochs=20,
                               batch_size=512,
                               validation_data=(x_test, y_test))

dpt_model_val_loss = dpt_model_hist.history['val_loss']

plt.plot(epochs, original_val_loss, 'b+', label='Original model')
plt.plot(epochs, dpt_model_val_loss, 'bo', label='Dropout-regularized model')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend()

plt.show()
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])
# Epoch 1/20
# 49/49 [==============================] - 3s 53ms/step - loss: 0.5392 - acc: 0.7430 - val_loss: 0.3319 - val_acc: 0.8836
# Epoch 2/20
# 49/49 [==============================] - 2s 49ms/step - loss: 0.2656 - acc: 0.9125 - val_loss: 0.3025 - val_acc: 0.8793
# Epoch 3/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.1944 - acc: 0.9318 - val_loss: 0.2838 - val_acc: 0.8861
# Epoch 4/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1584 - acc: 0.9456 - val_loss: 0.2923 - val_acc: 0.8838
# Epoch 5/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.1366 - acc: 0.9544 - val_loss: 0.3119 - val_acc: 0.8798
# Epoch 6/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.1164 - acc: 0.9594 - val_loss: 0.3339 - val_acc: 0.8755
# Epoch 7/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1055 - acc: 0.9662 - val_loss: 0.3699 - val_acc: 0.8685
# Epoch 8/20
# 49/49 [==============================] - 2s 51ms/step - loss: 0.0881 - acc: 0.9725 - val_loss: 0.4014 - val_acc: 0.8628
# Epoch 9/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0780 - acc: 0.9764 - val_loss: 0.4171 - val_acc: 0.8645
# Epoch 10/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0705 - acc: 0.9784 - val_loss: 0.4467 - val_acc: 0.8612
# Epoch 11/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.0609 - acc: 0.9825 - val_loss: 0.4696 - val_acc: 0.8612
# Epoch 12/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0485 - acc: 0.9858 - val_loss: 0.5319 - val_acc: 0.8511
# Epoch 13/20
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0475 - acc: 0.9885 - val_loss: 0.5366 - val_acc: 0.8580
# Epoch 14/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0394 - acc: 0.9895 - val_loss: 0.5681 - val_acc: 0.8566
# Epoch 15/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0328 - acc: 0.9914 - val_loss: 0.6017 - val_acc: 0.8540
# Epoch 16/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0283 - acc: 0.9931 - val_loss: 0.6391 - val_acc: 0.8524
# Epoch 17/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.0233 - acc: 0.9946 - val_loss: 0.6743 - val_acc: 0.8522
# Epoch 18/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0189 - acc: 0.9956 - val_loss: 0.7160 - val_acc: 0.8499
# Epoch 19/20
# 49/49 [==============================] - 2s 51ms/step - loss: 0.0155 - acc: 0.9968 - val_loss: 0.7620 - val_acc: 0.8489
# Epoch 20/20
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0155 - acc: 0.9963 - val_loss: 0.8697 - val_acc: 0.8376
# Epoch 1/20
# 49/49 [==============================] - 3s 56ms/step - loss: 0.5936 - acc: 0.7191 - val_loss: 0.4216 - val_acc: 0.8608
# Epoch 2/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.3569 - acc: 0.8969 - val_loss: 0.3318 - val_acc: 0.8843
# Epoch 3/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.2738 - acc: 0.9164 - val_loss: 0.2967 - val_acc: 0.8882
# Epoch 4/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2196 - acc: 0.9311 - val_loss: 0.2818 - val_acc: 0.8902
# Epoch 5/20
# 49/49 [==============================] - 2s 48ms/step - loss: 0.1881 - acc: 0.9391 - val_loss: 0.2922 - val_acc: 0.8810
# Epoch 6/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1691 - acc: 0.9443 - val_loss: 0.2855 - val_acc: 0.8852
# Epoch 7/20
# 49/49 [==============================] - 2s 49ms/step - loss: 0.1519 - acc: 0.9517 - val_loss: 0.2895 - val_acc: 0.8845
# Epoch 8/20
# 49/49 [==============================] - 2s 48ms/step - loss: 0.1370 - acc: 0.9558 - val_loss: 0.2980 - val_acc: 0.8828
# Epoch 9/20
# 49/49 [==============================] - 2s 48ms/step - loss: 0.1262 - acc: 0.9624 - val_loss: 0.3084 - val_acc: 0.8800
# Epoch 10/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1148 - acc: 0.9641 - val_loss: 0.3207 - val_acc: 0.8771
# Epoch 11/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1072 - acc: 0.9688 - val_loss: 0.3431 - val_acc: 0.8718
# Epoch 12/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1011 - acc: 0.9704 - val_loss: 0.3510 - val_acc: 0.8731
# Epoch 13/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0882 - acc: 0.9738 - val_loss: 0.3610 - val_acc: 0.8722
# Epoch 14/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0851 - acc: 0.9744 - val_loss: 0.3780 - val_acc: 0.8680
# Epoch 15/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.0769 - acc: 0.9786 - val_loss: 0.3920 - val_acc: 0.8680
# Epoch 16/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.0725 - acc: 0.9811 - val_loss: 0.4086 - val_acc: 0.8661
# Epoch 17/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.0641 - acc: 0.9834 - val_loss: 0.4273 - val_acc: 0.8642
# Epoch 18/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.0615 - acc: 0.9836 - val_loss: 0.4449 - val_acc: 0.8623
# Epoch 19/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0574 - acc: 0.9857 - val_loss: 0.4611 - val_acc: 0.8619
# Epoch 20/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0474 - acc: 0.9889 - val_loss: 0.4822 - val_acc: 0.8609
# Epoch 1/20
# 49/49 [==============================] - 17s 345ms/step - loss: 0.6119 - acc: 0.7236 - val_loss: 0.3574 - val_acc: 0.8445
# Epoch 2/20
# 49/49 [==============================] - 16s 326ms/step - loss: 0.2347 - acc: 0.9028 - val_loss: 0.3332 - val_acc: 0.8601
# Epoch 3/20
# 49/49 [==============================] - 16s 337ms/step - loss: 0.1276 - acc: 0.9529 - val_loss: 0.3877 - val_acc: 0.8642
# Epoch 4/20
# 49/49 [==============================] - 16s 335ms/step - loss: 0.0651 - acc: 0.9810 - val_loss: 0.4517 - val_acc: 0.8822
# Epoch 5/20
# 49/49 [==============================] - 16s 330ms/step - loss: 0.0633 - acc: 0.9892 - val_loss: 0.5083 - val_acc: 0.8835
# Epoch 6/20
# 49/49 [==============================] - 17s 346ms/step - loss: 0.0025 - acc: 0.9996 - val_loss: 0.6958 - val_acc: 0.8812
# Epoch 7/20
# 49/49 [==============================] - 17s 340ms/step - loss: 0.1380 - acc: 0.9854 - val_loss: 0.6517 - val_acc: 0.8793
# Epoch 8/20
# 49/49 [==============================] - 16s 332ms/step - loss: 4.5486e-04 - acc: 1.0000 - val_loss: 1.1014 - val_acc: 0.8378
# Epoch 9/20
# 49/49 [==============================] - 16s 337ms/step - loss: 0.2150 - acc: 0.9736 - val_loss: 0.7222 - val_acc: 0.8789
# Epoch 10/20
# 49/49 [==============================] - 16s 334ms/step - loss: 0.0022 - acc: 0.9998 - val_loss: 3.1942 - val_acc: 0.6984
# Epoch 11/20
# 49/49 [==============================] - 16s 329ms/step - loss: 0.1152 - acc: 0.9837 - val_loss: 0.8026 - val_acc: 0.8772
# Epoch 12/20
# 49/49 [==============================] - 16s 335ms/step - loss: 0.0119 - acc: 0.9988 - val_loss: 0.6737 - val_acc: 0.8737
# Epoch 13/20
# 49/49 [==============================] - 17s 347ms/step - loss: 5.7532e-04 - acc: 1.0000 - val_loss: 0.7942 - val_acc: 0.8766
# Epoch 14/20
# 49/49 [==============================] - 17s 339ms/step - loss: 0.0034 - acc: 0.9996 - val_loss: 1.1523 - val_acc: 0.8372
# Epoch 15/20
# 49/49 [==============================] - 16s 337ms/step - loss: 0.0051 - acc: 0.9986 - val_loss: 0.8799 - val_acc: 0.8749
# Epoch 16/20
# 49/49 [==============================] - 16s 330ms/step - loss: 1.0666e-04 - acc: 1.0000 - val_loss: 1.6390 - val_acc: 0.8186
# Epoch 17/20
# 49/49 [==============================] - 16s 339ms/step - loss: 0.1840 - acc: 0.9758 - val_loss: 0.9262 - val_acc: 0.8720
# Epoch 18/20
# 49/49 [==============================] - 17s 347ms/step - loss: 4.7831e-05 - acc: 1.0000 - val_loss: 1.0567 - val_acc: 0.8737
# Epoch 19/20
# 49/49 [==============================] - 16s 333ms/step - loss: 9.8322e-06 - acc: 1.0000 - val_loss: 1.2239 - val_acc: 0.8760
# Epoch 20/20
# 49/49 [==============================] - 17s 342ms/step - loss: 1.3208e-06 - acc: 1.0000 - val_loss: 1.4196 - val_acc: 0.8744
# Epoch 1/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.6592 - acc: 0.6791 - val_loss: 0.5029 - val_acc: 0.8714
# Epoch 2/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.4418 - acc: 0.8856 - val_loss: 0.3933 - val_acc: 0.8812
# Epoch 3/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.3396 - acc: 0.9118 - val_loss: 0.3603 - val_acc: 0.8833
# Epoch 4/20
# 49/49 [==============================] - 2s 48ms/step - loss: 0.2945 - acc: 0.9214 - val_loss: 0.3427 - val_acc: 0.8881
# Epoch 5/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.2715 - acc: 0.9269 - val_loss: 0.3556 - val_acc: 0.8803
# Epoch 6/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.2517 - acc: 0.9358 - val_loss: 0.3473 - val_acc: 0.8832
# Epoch 7/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.2342 - acc: 0.9415 - val_loss: 0.3657 - val_acc: 0.8776
# Epoch 8/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.2322 - acc: 0.9390 - val_loss: 0.3591 - val_acc: 0.8786
# Epoch 9/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.2292 - acc: 0.9399 - val_loss: 0.3582 - val_acc: 0.8808
# Epoch 10/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2198 - acc: 0.9458 - val_loss: 0.3613 - val_acc: 0.8810
# Epoch 11/20
# 49/49 [==============================] - 2s 47ms/step - loss: 0.2169 - acc: 0.9469 - val_loss: 0.4053 - val_acc: 0.8636
# Epoch 12/20
# 49/49 [==============================] - 2s 50ms/step - loss: 0.2097 - acc: 0.9487 - val_loss: 0.3811 - val_acc: 0.8747
# Epoch 13/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1998 - acc: 0.9542 - val_loss: 0.3802 - val_acc: 0.8763
# Epoch 14/20
# 49/49 [==============================] - 2s 48ms/step - loss: 0.2040 - acc: 0.9517 - val_loss: 0.3834 - val_acc: 0.8753
# Epoch 15/20
# 49/49 [==============================] - 3s 53ms/step - loss: 0.1980 - acc: 0.9512 - val_loss: 0.4190 - val_acc: 0.8678
# Epoch 16/20
# 49/49 [==============================] - 3s 53ms/step - loss: 0.1969 - acc: 0.9537 - val_loss: 0.3934 - val_acc: 0.8729
# Epoch 17/20
# 49/49 [==============================] - 3s 55ms/step - loss: 0.1891 - acc: 0.9547 - val_loss: 0.4158 - val_acc: 0.8692
# Epoch 18/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.1894 - acc: 0.9542 - val_loss: 0.4032 - val_acc: 0.8705
# Epoch 19/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.1874 - acc: 0.9557 - val_loss: 0.4731 - val_acc: 0.8487
# Epoch 20/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.1832 - acc: 0.9564 - val_loss: 0.4100 - val_acc: 0.8703
# Epoch 1/20
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6361 - acc: 0.6288 - val_loss: 0.4701 - val_acc: 0.8563
# Epoch 2/20
# 49/49 [==============================] - 2s 47ms/step - loss: 0.4655 - acc: 0.8281 - val_loss: 0.3651 - val_acc: 0.8831
# Epoch 3/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.3822 - acc: 0.8742 - val_loss: 0.3141 - val_acc: 0.8899
# Epoch 4/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.3294 - acc: 0.8980 - val_loss: 0.2937 - val_acc: 0.8907
# Epoch 5/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.2865 - acc: 0.9138 - val_loss: 0.2905 - val_acc: 0.8886
# Epoch 6/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2531 - acc: 0.9235 - val_loss: 0.2919 - val_acc: 0.8885
# Epoch 7/20
# 49/49 [==============================] - 2s 49ms/step - loss: 0.2338 - acc: 0.9280 - val_loss: 0.3112 - val_acc: 0.8873
# Epoch 8/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.2222 - acc: 0.9305 - val_loss: 0.3463 - val_acc: 0.8806
# Epoch 9/20
# 49/49 [==============================] - 2s 47ms/step - loss: 0.1924 - acc: 0.9421 - val_loss: 0.3559 - val_acc: 0.8794
# Epoch 10/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.1764 - acc: 0.9463 - val_loss: 0.3539 - val_acc: 0.8826
# Epoch 11/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.1670 - acc: 0.9502 - val_loss: 0.3684 - val_acc: 0.8810
# Epoch 12/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1668 - acc: 0.9501 - val_loss: 0.3996 - val_acc: 0.8809
# Epoch 13/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.1510 - acc: 0.9550 - val_loss: 0.4005 - val_acc: 0.8724
# Epoch 14/20
# 49/49 [==============================] - 2s 51ms/step - loss: 0.1484 - acc: 0.9551 - val_loss: 0.4217 - val_acc: 0.8785
# Epoch 15/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1378 - acc: 0.9600 - val_loss: 0.4586 - val_acc: 0.8765
# Epoch 16/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1337 - acc: 0.9611 - val_loss: 0.5093 - val_acc: 0.8754
# Epoch 17/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.1307 - acc: 0.9607 - val_loss: 0.5017 - val_acc: 0.8749
# Epoch 18/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.1261 - acc: 0.9641 - val_loss: 0.5390 - val_acc: 0.8718
# Epoch 19/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.1158 - acc: 0.9662 - val_loss: 0.5621 - val_acc: 0.8737
# Epoch 20/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1075 - acc: 0.9695 - val_loss: 0.6204 - val_acc: 0.8696
